# %% [markdown]
# # ❤️ Heart Disease — Your First Classification
#
# Theme of this project: **accuracy is not enough.** Keep asking "which kind of mistake is this model making?"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import (accuracy_score, confusion_matrix,
                             classification_report, ConfusionMatrixDisplay)

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"
cols = ["age","sex","cp","trestbps","chol","fbs","restecg","thalach",
        "exang","oldpeak","slope","ca","thal","target"]
df = pd.read_csv(url, names=cols, na_values="?")
df.head()

# %% [markdown]
# ## Step 1 — Clean & binarize
#
# 1. Count missing values per column
# 2. Drop rows that have any (only ~6 rows)
# 3. Replace the target: 0 stays 0, anything > 0 becomes 1

# %%
# TODO: missing values per column

# TODO: drop rows with missing values

# TODO: binarize the target column

# %% [markdown]
# ## Step 2 — Class balance = your baseline
#
# Use `value_counts(normalize=True)` on the target. The larger share is the accuracy a model gets by **always predicting the majority class**. Remember that number!

# %%
# TODO: class balance

# Baseline accuracy to beat (comment): ...

# %% [markdown]
# ## Step 3 — Split (stratified!)
#
# `train_test_split(..., test_size=0.2, stratify=y, random_state=42)`
#
# With only ~300 rows, stratifying keeps the disease ratio identical in train and test.

# %%
# TODO: build X (all features) and y (target), then split with stratify

# %% [markdown]
# ## Step 4 — Logistic regression + confusion matrix
#
# Fit `LogisticRegression(max_iter=1000)`, predict on the test set.
#
# Then plot the confusion matrix (`ConfusionMatrixDisplay.from_estimator`) and identify in a comment which cell holds the **false negatives** — the sick patients the model called healthy.

# %%
# TODO: fit logistic regression and predict

# TODO: accuracy + confusion matrix plot

# Which cell are the false negatives, and how many are there? ...

# %% [markdown]
# ## Step 5 — Precision, recall, F1
#
# Print the `classification_report`. Then answer **in the markdown cell below**: in medical screening, is a false positive or a false negative worse? So which metric matters most here?

# %%
# TODO: classification report

# %% [markdown]
# *Your answer (which error is worse and which metric to optimize):* ...

# %% [markdown]
# ## Step 6 — kNN with a Pipeline
#
# Build `make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=k))` for k = 3, 5, 11. For each, print test accuracy and recall.
#
# **Why the Pipeline matters:** it fits the scaler on the training fold only. Scaling X before the split would leak test-set statistics into training — one of the most common silent bugs in ML.

# %%
# TODO: loop over k in [3, 5, 11], fit pipeline, print accuracy + recall

# %% [markdown]
# ## Step 7 — The uncertain patients
#
# Get `predict_proba(X_test)[:, 1]` from your best model and find the 5 patients whose probability is closest to 0.5. These are the cases where the model is essentially guessing.

# %%
# TODO: probabilities, distance from 0.5, show the 5 most uncertain patients

# %% [markdown]
# ## Step 8 — Recommendation
#
# Three sentences: which model do you recommend, on which metric did you base that, and what would you want before using this in a real clinic?
#
# *Your recommendation:* ...
