# %% [markdown]
# # 🛒 Customer Segmentation (RFM + k-means)
#
# See README for goal, download link, and success criteria.
#
# **Prerequisite:** the UCI Online Retail `.xlsx` must be in `../data/raw/`.

# %%
# Starting point: first load is slow — cache to parquet afterwards.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

cache = Path("../data/processed/online_retail.parquet")
if cache.exists():
    df = pd.read_parquet(cache)
else:
    df = pd.read_excel("../data/raw/Online Retail.xlsx")
    df.to_parquet(cache)
df.head()

# %% [markdown]
# ## 1. Cleaning (cancellations, missing IDs, negative quantities)

# %% [markdown]
# ## 2. RFM aggregation: one row per customer

# %% [markdown]
# ## 3. Distributions, transforms, scaling

# %% [markdown]
# ## 4. Choosing k: elbow + silhouette

# %% [markdown]
# ## 5. Fit k-means & profile the clusters

# %% [markdown]
# ## 6. Visualization

# %% [markdown]
# ## 7. Stability checks (seeds, k±1)

# %% [markdown]
# ## 8. Stretch: DBSCAN / hierarchical comparison
