# %% [markdown]
# # 🧪 A/B Test Analysis — Cookie Cats
#
# See README. Deliver a defensible ship / don't-ship recommendation.
#
# **Prerequisite:** put `cookie_cats.csv` in `../data/raw/`.

# %%
# Starting point: load the experiment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("../data/raw/cookie_cats.csv")
# version: gate_30 (control) vs gate_40 (treatment)
df.groupby("version")[["retention_1", "retention_7", "sum_gamerounds"]].mean()

# %% [markdown]
# ## 1. Sanity checks FIRST — group sizes, duplicate users, balance (before any outcome)

# %% [markdown]
# ## 2. Pick the primary metric (retention_7) and commit to it before peeking

# %% [markdown]
# ## 3. Retention: rates, difference, CI for the difference, two-proportion test

# %% [markdown]
# ## 4. sum_gamerounds is skewed with outliers — justify your method (bootstrap / rank test, not a naive mean t-test)

# %% [markdown]
# ## 5. Bootstrap the treatment effect and plot its uncertainty

# %% [markdown]
# ## 6. Multiple-comparisons caveat + final ship / don't-ship verdict in plain language
