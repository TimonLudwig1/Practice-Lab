# %% [markdown]
# # 🚲 Bike Rental Demand Forecasting
#
# See README for goal, download link, and success criteria.
#
# **Prerequisite:** unzip the UCI dataset into `../data/raw/` so that `../data/raw/day.csv` exists.

# %%
# Starting point: load and index by date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("../data/raw/day.csv", parse_dates=["dteday"])
df = df.set_index("dteday").sort_index()
df[["cnt", "temp", "hum", "windspeed", "workingday"]].head()

# %% [markdown]
# ## 1. EDA over time

# %% [markdown]
# ## 2. Naive baselines (lag-1 and seasonal lag-7)

# %% [markdown]
# ## 3. Feature engineering: lags, rolling stats, calendar

# %% [markdown]
# ## 4. Time-based validation setup

# %% [markdown]
# ## 5. Models: linear vs gradient boosting

# %% [markdown]
# ## 6. Error analysis: the worst days

# %% [markdown]
# ## 7. Stretch: SARIMAX comparison
