# %% [markdown]
# # 📞 Telco Customer Churn
#
# See README for goal and success criteria.

# %%
# Starting point: data loading (also save a copy to ../data/raw/)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = ("https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/"
       "master/data/Telco-Customer-Churn.csv")
df = pd.read_csv(url)
df.to_csv("../data/raw/telco_churn.csv", index=False)
df.head()

# %% [markdown]
# ## 1. EDA: who churns?

# %% [markdown]
# ## 2. Cleaning (hint: check the dtype of TotalCharges)

# %% [markdown]
# ## 3. Preprocessing pipeline (ColumnTransformer)

# %% [markdown]
# ## 4. Feature engineering + impact measurement (CV)

# %% [markdown]
# ## 5. Models: logistic regression vs tree ensemble

# %% [markdown]
# ## 6. Evaluation on imbalanced data: ROC-AUC, PR-AUC

# %% [markdown]
# ## 7. Business threshold: 10€ offer vs 200€ customer value
