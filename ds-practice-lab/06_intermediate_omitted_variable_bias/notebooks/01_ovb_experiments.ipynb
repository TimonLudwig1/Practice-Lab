# %% [markdown]
# # 📉 Omitted Variable Bias Experiments
#
# See README for goal and success criteria.

# %%
# Starting point: skeleton of the data-generating process. You choose the true parameters.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

rng = np.random.default_rng(7)
n = 5_000

ability = rng.normal(0, 1, n)               # unobserved confounder
# TODO: education = f(ability) + noise      <- must correlate with ability
# TODO: wage = b0 + b1*education + b2*ability + noise   <- you pick b1, b2

# df = pd.DataFrame({"ability": ability, "education": ..., "wage": ...})

# %% [markdown]
# ## 1. Data-generating process & true parameters

# %% [markdown]
# ## 2. Short regression (confounder omitted) vs long regression

# %% [markdown]
# ## 3. Verify the OVB formula: bias = β₂ · δ

# %% [markdown]
# ## 4. Bias heatmap: correlation × effect strength

# %% [markdown]
# ## 5. Real-data transfer: confounding in the mpg dataset

# %% [markdown]
# ## 6. Lessons learned
