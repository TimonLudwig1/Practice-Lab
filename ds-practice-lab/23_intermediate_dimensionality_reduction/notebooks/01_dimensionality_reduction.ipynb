# %% [markdown]
# # 🗺️ Dimensionality Reduction & Manifold Learning
#
# See README. Labels are used **only to color plots**, never to fit the reductions.

# %%
# Starting point: load digits (64-dim, built in)
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

digits = load_digits()
X, y = digits.data, digits.target   # X: (1797, 64), y used for coloring only
X.shape, np.unique(y)

# %% [markdown]
# ## 1. Standardize, fit PCA, plot explained + cumulative variance (how many comps for 90%?)

# %% [markdown]
# ## 2. 2D PCA scatter colored by label + visualize top components as 8×8 'eigen-digits'

# %% [markdown]
# ## 3. t-SNE to 2D — compare the scatter to PCA

# %% [markdown]
# ## 4. Read t-SNE critically: vary perplexity, list what distances/sizes do NOT mean

# %% [markdown]
# ## 5. (Optional) UMAP comparison

# %% [markdown]
# ## 6. Downstream check: classifier accuracy on top-k PCA comps vs all 64 features
