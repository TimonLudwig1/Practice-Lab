# %% [markdown]
# # 🎯 Sample Bias Laboratory
#
# See README for the goal and success criteria. Sections below are a suggested structure — adapt as you see fit.

# %%
# Starting point: a population generator skeleton. Extend the dependencies as you like.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

rng = np.random.default_rng(42)
N = 200_000

age = rng.integers(18, 90, size=N)
income = rng.normal(2000 + 40 * np.clip(age, 18, 55), 800).clip(500, None)
# TODO: smartphone ownership probability should DECREASE with age
# TODO: daily screen time should depend on age and smartphone ownership
# TODO: an opinion/preference variable correlated with age

population = pd.DataFrame({"age": age, "income": income})
population.describe()

# %% [markdown]
# ## 1. Ground truth: population parameters

# %% [markdown]
# ## 2. Reference: simple random sampling (unbiased)

# %% [markdown]
# ## 3. Biased scheme A: convenience sample

# %% [markdown]
# ## 4. Biased scheme B: voluntary response / self-selection

# %% [markdown]
# ## 5. Biased scheme C: survivorship-style filter

# %% [markdown]
# ## 6. Comparison: sampling distributions vs truth

# %% [markdown]
# ## 7. Correction: post-stratification / weighting

# %% [markdown]
# ## 8. Bonus: Literary Digest 1936 in miniature

# %% [markdown]
# ## 9. Conclusions
